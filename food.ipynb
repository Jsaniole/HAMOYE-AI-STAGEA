# %%
import pandas as pd
import numpy as np
food = pd.read_csv('FoodBalanceSheets.csv')
print(food)
# Out:
#       Area Code        Area  Item Code         Item  Element Code  \
# 0             4     Algeria       2501   Population           511
# 1             4     Algeria       2501   Population          5301
# 2             4     Algeria       2901  Grand Total           664
# 3             4     Algeria       2901  Grand Total           674
# 4             4     Algeria       2901  Grand Total           684
# ...         ...         ...        ...          ...           ...
# 7485         35  Cabo Verde       2615      Bananas          5142
# 7486         35  Cabo Verde       2615      Bananas           645
# 7487         35  Cabo Verde       2615      Bananas           664
# 7488         35  Cabo Verde       2615      Bananas           674
# 7489         35  Cabo Verde       2615      Bananas           684
#
#                                      Element             Unit     Y2014  \
# 0              Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\Data Analysis'

# %%
food.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
# Element           0
# Unit              0
# Y2014           202
# Y2015           187
# Y2016           168
# Y2017           154
# Y2018           167
# dtype: int64

# %%
food.groupby('Y2014').count()
# Out:
#           Area Code  Area  Item Code  Item  Element Code  Element  Unit  \
# Y2014
# -374.0            1     1          1     1             1        1     1
# -368.0            1     1          1     1             1        1     1
# -50.0             1     1          1     1             1        1     1
# -39.0             1     1          1     1             1        1     1
# -34.0             1     1          1     1             1        1     1
# ...             ...   ...        ...   ...           ...      ...   ...
#  12604.0          1     1          1     1             1        1     1
#  15353.0          1     1          1     1             1        1     1
#  17586.0          1     1          1     1             1        1     1
#  26942.0          1     1          1     1             1        1     1
#  38924.0          1     1          1     1             1        1     1
#
#           Y2015  Y2016  Y2017  Y2018
# Y2014
# -374.0        1      1      1      1
# ...

# %%
food.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code     Y2014     Y2015  \
# Item
# Alcohol, Non-Food         2135      82429        166645    134.00    123.00
# Alcoholic Beverages       4068     187136        248251  21571.28  19960.55
# Animal Products           1056      52938         12132   2212.48   2100.03
# Animal fats               4641     209166        285306  11346.29  14253.59
# Apples and products       3678     149169        211459   2015.17   1981.78
# ...                        ...        ...           ...       ...       ...
# Vegetables, Other         4763     205795        310215  19483.32  20374.65
# Vegetal Products          1056      52254         12132  14805.29  14850.15
# Wheat and products        5040     228501        373872  36614.26  39460.92
# Wine                      3675     151335        211490    497.94    322.84
# Yams                      3723     119145        195419   9817.05   8776.29
#
#                         Y2016     Y2017     Y2018
# ...

# %%
food.describe()
# Out:
#          Area Code    Item Code  Element Code         Y2014         Y2015  \
# count  7490.000000  7490.000000   7490.000000   7288.000000   7303.000000
# mean     61.818024  2681.904673   3832.078505    106.993808    106.775060
# std      84.090397   147.086703   2204.025902    824.240740    841.706727
# min       4.000000  2501.000000    511.000000   -374.000000   -294.000000
# 25%       7.000000  2560.000000    684.000000      0.000000      0.000000
# 50%      20.000000  2618.500000   5142.000000      0.090000      0.080000
# 75%      53.000000  2769.000000   5511.000000      9.405000      9.000000
# max     233.000000  2961.000000   5911.000000  38924.000000  39728.000000
#
#               Y2016         Y2017         Y2018
# count   7322.000000   7336.000000   7323.000000
# mean     109.490858    111.216223    116.121487
# std      862.620472    882.189200    913.793985
# min     -142.000000   -281.000000   -256.000000
# 25%        0.000000      0.000000      0.000000
# ...

# %%
food.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    39477    1733353       3435048
# Export Quantity                             31771    1451161       3197851
# Fat supply quantity (g/capita/day)          37479    1641433        417240
# Feed                                        10098     433507        894402
# Food                                        36718    1599279       3064632
# Food supply (kcal/capita/day)               37006    1633453        403048
# Food supply quantity (kg/capita/yr)         36718    1599279        384420
# Import Quantity                             38714    1697936       3557374
# Losses                                      13633     626248       1188536
# Other uses (non-food)                       14456     563814       1066878
# Processing                                  21611     635617       1226309
# ...

# %%
food.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    39477    1733353       3435048
# Export Quantity                             31771    1451161       3197851
# Fat supply quantity (g/capita/day)          37479    1641433        417240
# Feed                                        10098     433507        894402
# Food                                        36718    1599279       3064632
# Food supply (kcal/capita/day)               37006    1633453        403048
# Food supply quantity (kg/capita/yr)         36718    1599279        384420
# Import Quantity                             38714    1697936       3557374
# Losses                                      13633     626248       1188536
# Other uses (non-food)                       14456     563814       1066878
# Processing                                  21611     635617       1226309
# ...

# %%
food.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  210355.55
# Export Quantity                            10693.10
# Fat supply quantity (g/capita/day)          1474.64
# Feed                                       24297.74
# Food                                      140499.66
# Food supply (kcal/capita/day)              63196.00
# Food supply quantity (kg/capita/yr)         6946.15
# Import Quantity                            55893.26
# Losses                                     17695.00
# Other uses (non-food)                       9520.12
# Processing                                 14233.00
# Production                                173886.82
# Protein supply quantity (g/capita/day)      1645.05
# Residuals                                    778.00
# Seed                                        3316.00
# Stock Variation                             8851.56
# Total Population - Both sexes             107072.00
# Tourist consumption                            4.00
# ...

# %%
food.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  210355.55
# Export Quantity                            10693.10
# Fat supply quantity (g/capita/day)          1474.64
# Feed                                       24297.74
# Food                                      140499.66
# Food supply (kcal/capita/day)              63196.00
# Food supply quantity (kg/capita/yr)         6946.15
# Import Quantity                            55893.26
# Losses                                     17695.00
# Other uses (non-food)                       9520.12
# Processing                                 14233.00
# Production                                173886.82
# Protein supply quantity (g/capita/day)      1645.05
# Residuals                                    778.00
# Seed                                        3316.00
# Stock Variation                             8851.56
# Total Population - Both sexes             107072.00
# Tourist consumption                            4.00
# ...

# %%
food.groupby('Area').sum()
# Out:
#               Area Code  Item Code  Element Code      Y2014      Y2015  \
# Area
# Algeria            5252    3532053       5017927  313375.33  324058.40
# Angola             9968    3819908       5515088  208584.42  209565.67
# Benin             68105    3453692       4852820  118050.79  108181.13
# Botswana          27560    3704902       5259784   22339.92   23024.85
# Burkina Faso     328297    3778795       5431243  105051.33  102701.22
# Cabo Verde        23835    1798116       2625406   12369.08   12246.99
#
#                   Y2016      Y2017      Y2018
# Area
# Algeria       326007.41  325644.27  341729.98
# Angola        214725.32  229159.57  235206.68
# Benin         117963.59  124771.22  124960.70
# Botswana       22970.65   22101.30   23129.08
# Burkina Faso  107702.27  101855.07  112970.72
# Cabo Verde     12322.82   12350.78   12360.49

# %%
food.describe()
# Out:
#          Area Code    Item Code  Element Code         Y2014         Y2015  \
# count  7490.000000  7490.000000   7490.000000   7288.000000   7303.000000
# mean     61.818024  2681.904673   3832.078505    106.993808    106.775060
# std      84.090397   147.086703   2204.025902    824.240740    841.706727
# min       4.000000  2501.000000    511.000000   -374.000000   -294.000000
# 25%       7.000000  2560.000000    684.000000      0.000000      0.000000
# 50%      20.000000  2618.500000   5142.000000      0.090000      0.080000
# 75%      53.000000  2769.000000   5511.000000      9.405000      9.000000
# max     233.000000  2961.000000   5911.000000  38924.000000  39728.000000
#
#               Y2016         Y2017         Y2018
# count   7322.000000   7336.000000   7323.000000
# mean     109.490858    111.216223    116.121487
# std      862.620472    882.189200    913.793985
# min     -142.000000   -281.000000   -256.000000
# 25%        0.000000      0.000000      0.000000
# ...

# %%
food.count()
# Out:
# Area Code       7490
# Area            7490
# Item Code       7490
# Item            7490
# Element Code    7490
# Element         7490
# Unit            7490
# Y2014           7288
# Y2015           7303
# Y2016           7322
# Y2017           7336
# Y2018           7323
# dtype: int64

# %%
food.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria         1313
# Angola          1424
# Benin           1285
# Botswana        1378
# Burkina Faso    1409
# Cabo Verde       681
# Name: Area, dtype: int64

# %%
food.groupby('Item')['Y2017'].sum()
food.groupby('Element')['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  195284.90
# Export Quantity                             5432.75
# Fat supply quantity (g/capita/day)          1504.88
# Feed                                       22148.46
# Food                                      131977.00
# Food supply (kcal/capita/day)              63612.00
# Food supply quantity (kg/capita/yr)         7248.74
# Import Quantity                            54973.58
# Losses                                     16242.00
# Other uses (non-food)                       9739.44
# Processing                                 12306.00
# Production                                152076.08
# Protein supply quantity (g/capita/day)      1703.06
# Residuals                                    484.00
# Seed                                        2344.00
# Stock Variation                             6332.98
# Total Population - Both sexes              96346.00
# Tourist consumption                           15.00
# ...

# %%
food.duplicated().any()
# Out:
# False

# %%
food.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
# Element           0
# Unit              0
# Y2014           202
# Y2015           187
# Y2016           168
# Y2017           154
# Y2018           167
# dtype: int64

# %%
food [['Y2014']] = food[['Y2014']].fillna(value='0')

# %%
food.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
# Element           0
# Unit              0
# Y2014             0
# Y2015           187
# Y2016           168
# Y2017           154
# Y2018           167
# dtype: int64

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7490 entries, 0 to 7489
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     7490 non-null   int64
#  1   Area          7490 non-null   object
#  2   Item Code     7490 non-null   int64
#  3   Item          7490 non-null   object
#  4   Element Code  7490 non-null   int64
#  5   Element       7490 non-null   object
#  6   Unit          7490 non-null   object
#  7   Y2014         7490 non-null   object
#  8   Y2015         7303 non-null   float64
#  9   Y2016         7322 non-null   float64
#  10  Y2017         7336 non-null   float64
#  11  Y2018         7323 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 702.3+ KB

# %%
for col in food:
    print(col)
    print(food[col].nunique())
    print()
# Out:
# Area Code
# 6
#
# Area
# 6
#
# Item Code
# 122
#
# Item
# 119
#
# Element Code
# 18
#
# Element
# 18
#
# Unit
# 5
#
# Y2014
# 1156
#
# Y2015
# 1148
#
# Y2016
# 1139
#
# Y2017
# 1158
#
# Y2018
# 1175
